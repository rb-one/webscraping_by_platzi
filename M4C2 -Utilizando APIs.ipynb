# %% [markdown]
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.D4OdoQPu4JwSoew58891QAHaFB%26pid%3DApi&f=1">

# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{id}'

# %%
id_im = '6mdiAmATAx73kdxrNrnlao'

# %%
#Construimos la url completa
url_base+ep_artist.format(id=id_im)
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
import requests

# %%
r = requests.get(url_base+ep_artist.format(id=id_im))

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %% [markdown]
# #### Utilizando APIs: Tokens y Búsqueda

# %% [markdown]
# - [encode base 64](https://www.base64encode.org/)
# - [Authorization Guide | Spotify for Developers](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %%
#Utilizaremos la basic strategy para autorizacion
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials' }

# %%
headers = {'Authorization': 'Basic MWNiMDlhZjllODljNDRmZTllZGZhNGQzOWNiYjBmMGY6NzcwN2I1YzFiODhhNDExNTk1YjU0MjMwYTVhMmY4NDg'}

# %%
 r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQCV5lfA3qWQezcnS6XpIx2DgjVvAS_5u6jkIcEzv69qXvL4sdncURzoDZIVzGunKsytyqzM0SYOG7dTtuo',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']

# %% [markdown]
# ### Hacemos de nuevo la solicitud a la api ya con el token

# %%
header = {'Authorization': f'Bearer {token}'}

# %%
r = requests.get(url_base+ep_artist.format(id=id_im), headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 5376602},
#  'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/9b47777582da7ee93a65c89d1d28688cc0e6225b',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/2f50e6730873b368928778b6507a682e6d1605af',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/c975d9b04dd8b53b3eb4a61b556743352127b399',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 77,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %% [markdown]
# ### Implementando una url de busqueda

# %%
url_busqueda  = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q': "Iron+Maiden", 'type': 'artist', 'market': 'AR'}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
print(busqueda.json()['artists'])
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=Iron%2BMaiden&type=artist&market=AR&offset=0&limit=20', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'}, 'followers': {'href': None, 'total': 5376602}, 'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'], 'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao', 'id': '6mdiAmATAx73kdxrNrnlao', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/9b47777582da7ee93a65c89d1d28688cc0e6225b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/2f50e6730873b368928778b6507a682e6d1605af', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/c975d9b04dd8b53b3eb4a61b556743352127b399', 'width': 160}], 'name': 'Iron Maiden', 'popularity': 77, 'type': 'artist', 'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2bb97mSGnF818Xcb86ewt7'}, 'followers': {'href': None, 'total': 345}, 'genres':
# ...

# %% [markdown]
# ### Creamos un DataFrame con los datos

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])

# %%
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/2...
# 2  {'spotify': 'https://open.spotify.com/artist/5...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                           followers  \
# 0  {'href': None, 'total': 5376602}
# 1      {'href': None, 'total': 344}
# 2     {'href': None, 'total': 1957}
# 3     {'href': None, 'total': 1064}
# 4      {'href': None, 'total': 370}
#
#                                          genres  \
# 0  [album rock, hard rock, metal, nwobhm, rock]
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
#
#                                                 href                      id  \
# ...

# %% [markdown]
# #### Ordenamos el df por popularidad del artista y obtenemos el id del mas popular

# %%
df.sort_values(by='popularity', ascending=False)
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/2...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 2  {'spotify': 'https://open.spotify.com/artist/5...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                           followers  \
# 0  {'href': None, 'total': 5376602}
# 1      {'href': None, 'total': 344}
# 3     {'href': None, 'total': 1064}
# 2     {'href': None, 'total': 1957}
# 4      {'href': None, 'total': 370}
#
#                                          genres  \
# 0  [album rock, hard rock, metal, nwobhm, rock]
# 1                                            []
# 3                                            []
# 2                                            []
# 4                                            []
#
#                                                 href                      id  \
# ...

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]
# Out:
# external_urls    {'spotify': 'https://open.spotify.com/artist/6...
# followers                         {'href': None, 'total': 5376602}
# genres                [album rock, hard rock, metal, nwobhm, rock]
# href             https://api.spotify.com/v1/artists/6mdiAmATAx7...
# id                                          6mdiAmATAx73kdxrNrnlao
# images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# name                                                   Iron Maiden
# popularity                                                      77
# type                                                        artist
# uri                          spotify:artist:6mdiAmATAx73kdxrNrnlao
# Name: 0, dtype: object

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %% [markdown]
# ### Obteniendo la discografia

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type': 'client_credentials'}
    headers = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', data=params, headers=headers)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    print('Token valido por {} segundos'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = '1cb09af9e89c44fe9edfa4d39cbb0f0f'

# %%
client_secret = '7707b5c1b88a411595b54230a5a2f848'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token valido por 3600 segundos

# %%
token
# Out:
# 'BQDTeZYLkjNN4lt6nN3zUXJoXLADx_SDOWJFSlN7JZQ_WggcD78Y5STcStbFa3mWSGwMpAfPkods2ydzR6Q'

# %%
header = {'Authorization': f'Bearer {token}'}

# %%
im_id = '6mdiAmATAx73kdxrNrnlao'

# %%
ep_albums = '/artists/{artist_id}/albums'

# %%
url_base+ep_albums
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %%
params = {'country': 'AR'}

# %%
albumns_im = requests.get(url_base+ep_albums.format(artist_id=id_iron_maiden),headers=header, params=params)

# %%
albumns_in.status_code
# Out:
# 200

# %%
albumns_im.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#    'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#    'id': '6mdiAmATAx73kdxrNrnlao',
#    'name': 'Iron Maiden',
#    'type': 'artist',
#    'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#  'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#  'id': '3oFAX7PeOFbZnKiPmpUPv4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#    'width': 64}],
#  'name': 'The Book of Souls: Live Chapter',
# ...

# %% [markdown]
# ### Obteniendo los albums

# %%
lista_albums = [(album['id'], album['name']) for album in albumns_im.json()['items']]
lista_albums
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock In Rio [Live]'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
#  ('0axV6lvqshTCcGxT2AYiIK', 'Ed Hunter'),
#  ('4olc018Cln2QaMRFy1sk7v', 'Virtual XI (2015 Remaster)'),
#  ('3irqbaStVsDR9IEdg8Cdwz', 'The X Factor (2015 Remaster)'),
#  ('3DRvgymMVPG0TQ2DugHJRb', 'A Real Live Dead One (Live; 2006 Remaster)'),
#  ('12vTiEGN96ZQtGb3zfpKE8', 'A Real Live One'),
# ...

# %%
album_ep = '/albums/{album_id}'
album_params = {'market': 'AR'}

# %%
bnw_id = '1hDF0QPIHVTnSJtxyQVguB'

# %%
bnw = requests.get(url_base+album_ep.format(album_id=bnw_id)+'/tracks', headers=header, params=album_params)
bnw
# Out:
# <Response [200]>

# %%
bnw.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'disc_number': 1,
#   'duration_ms': 275253,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1diuZVsxD74xvtUSABRUoF'},
#   'href': 'https://api.spotify.com/v1/tracks/1diuZVsxD74xvtUSABRUoF',
#   'id': '1diuZVsxD74xvtUSABRUoF',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'The Wicker Man - 2015 Remaster',
#   'preview_url': 'https://p.scdn.co/mp3-preview/647a53055a6f5d012ed238d87c3191df1ed5aff9?cid=1cb09af9e89c44fe9edfa4d39cbb0f0f',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1diuZVsxD74xvtUSABRUoF'},
# ...

# %%
[(track['id'], track['name']) for track in bnw.json()['items']]
# Out:
# [('1diuZVsxD74xvtUSABRUoF', 'The Wicker Man - 2015 Remaster'),
#  ('6KLUI6LnYdg5PIb5VKWSzu', 'Ghost of the Navigator - 2015 Remaster'),
#  ('5hAAcyKfcw8nJ2Kgx3FXd0', 'Brave New World - 2015 Remaster'),
#  ('4q9YY8eorYGjpjk3Zko7l9', 'Blood Brothers - 2015 Remaster'),
#  ('0WGBotn3YOsajQPxcNSgNi', 'The Mercenary - 2015 Remaster'),
#  ('2GJUBmvnT8mZ9IyuPS9SsI', 'Dream of Mirrors - 2015 Remaster'),
#  ('3rKzE0Dx4rLM2kQRfDYDZc', 'The Fallen Angel - 2015 Remaster'),
#  ('1QZPGP6Srliq75NFwtwwvL', 'The Nomad - 2015 Remaster'),
#  ('4UV7lyqZU3JmAZJjFO6DK8', 'Out of the Silent Planet - 2015 Remaster'),
#  ('7m0XcFYchWHV0EnerStmYg',
#   'The Thin Line Between Love and Hate - 2015 Remaster')]

# %% [markdown]
# ### Obteniendo los albums

# %%
def obtener_discografia(artist_id, token, return_name=False, page_limit=50, country=None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit,
              'offset': 0,
              'country': country}

    lista = []
    r = requests.get(url, params=params, headers=header)

    if r.status_code != 200:
        print('Error en la request.', json())
        return None

    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
         lista += [item['id'] for item in r.json()['items']] 

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
             lista += [item['id'] for item in r.json()['items']]   

    return lista

# %%
lista_im = obtener_discografia(im_id, token, True, 50, 'AR')
lista_im
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock In Rio [Live]'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
#  ('0axV6lvqshTCcGxT2AYiIK', 'Ed Hunter'),
#  ('4olc018Cln2QaMRFy1sk7v', 'Virtual XI (2015 Remaster)'),
#  ('3irqbaStVsDR9IEdg8Cdwz', 'The X Factor (2015 Remaster)'),
#  ('3DRvgymMVPG0TQ2DugHJRb', 'A Real Live Dead One (Live; 2006 Remaster)'),
#  ('12vTiEGN96ZQtGb3zfpKE8', 'A Real Live One'),
# ...

# %% [markdown]
# ### Obtener tracks

# %%
album_id = '0SmIkzc7YgxqBV0V5RcbPt'

def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    
    header = header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit,
              'offset': 0,
              'market': market}
    
    lista = []
    r = requests.get(url, params=params, headers=header)

    if r.status_code != 200:
        print('Error en la request.', json())
        return None

    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
         lista += [item['id'] for item in r.json()['items']] 

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
             lista += [item['id'] for item in r.json()['items']]   

    return lista   

tracks = obtener_tracks(album_id, token, True, 50, 'AR')
tracks
# Out:
# [('5POL3OxF0fzxV9U0jt0t4Z',
#   "Intro (Churchill's Speech) - Live at Long Beach Arena; 1998 Remaster"),
#  ('1XLGB01MnLAbCbrO0T6oFg', 'Aces High - Live; 1998 Remaster'),
#  ('4ke6ZfMhK70E6xJkWOisaK', '2 Minutes to Midnight - 1998 Remaster'),
#  ('6tVs6BS4vqrFsCrHS0Ycsr', 'The Trooper - 1998 Remaster'),
#  ('0ozNndH4mWI1bbcX0jT1X1', 'Wasted Years - 1998 Remaster'),
#  ('1yZogZFlWcIP3CkqJaPBeR', 'Children of the Damned - 1998 Remaster'),
#  ('4Oz664sN1BuTmREQjfMHkZ', 'The Number of the Beast - 1998 Remaster'),
#  ('4Z4ZLBzCXSlHSCaxZ3WS7p', 'Run to the Hills - 1998 Remaster'),
#  ('3U1Uvx78oIOqjrBVDdpxvp',
#   'Phantom of the Opera - Live at the Hammersmith Odeon; 1998 Remaster'),
#  ('2fx9BV0oC15Tz1xBPMSo9B', 'The Evil That Men Do - 1998 Remaster'),
#  ('3GMqr82tqfw8OY8Rrx4WVO',
#   'Wrathchild - Live at the Hammersmith Odeon; 1998 Remaster'),
#  ('4lXH1smoMUHWTUDc05Facc', 'Can I Play with Madness - 1998 Remaster'),
#  ('1Wk0ShT85IW78kRqM8Wh86', 'Powerslave - 1998 Remaster'),
# ...

# %%
album_id = '0SmIkzc7YgxqBV0V5RcbPt'

# %%
tracks = obtener_tracks(album_id, token, True, 50, 'AR')
tracks
# Out:
# [('5POL3OxF0fzxV9U0jt0t4Z',
#   "Intro (Churchill's Speech) - Live at Long Beach Arena; 1998 Remaster"),
#  ('1XLGB01MnLAbCbrO0T6oFg', 'Aces High - Live; 1998 Remaster'),
#  ('4ke6ZfMhK70E6xJkWOisaK', '2 Minutes to Midnight - 1998 Remaster'),
#  ('6tVs6BS4vqrFsCrHS0Ycsr', 'The Trooper - 1998 Remaster'),
#  ('0ozNndH4mWI1bbcX0jT1X1', 'Wasted Years - 1998 Remaster'),
#  ('1yZogZFlWcIP3CkqJaPBeR', 'Children of the Damned - 1998 Remaster'),
#  ('4Oz664sN1BuTmREQjfMHkZ', 'The Number of the Beast - 1998 Remaster'),
#  ('4Z4ZLBzCXSlHSCaxZ3WS7p', 'Run to the Hills - 1998 Remaster'),
#  ('3U1Uvx78oIOqjrBVDdpxvp',
#   'Phantom of the Opera - Live at the Hammersmith Odeon; 1998 Remaster'),
#  ('2fx9BV0oC15Tz1xBPMSo9B', 'The Evil That Men Do - 1998 Remaster'),
#  ('3GMqr82tqfw8OY8Rrx4WVO',
#   'Wrathchild - Live at the Hammersmith Odeon; 1998 Remaster'),
#  ('4lXH1smoMUHWTUDc05Facc', 'Can I Play with Madness - 1998 Remaster'),
#  ('1Wk0ShT85IW78kRqM8Wh86', 'Powerslave - 1998 Remaster'),
# ...

# %% [markdown]
# ### Final del proyecto

# %%
for album in obtener_discografia(im_id, token, True, 50, 'AR'):
    print(album[1])
    for track in obtener_tracks(album[0], token, True, 50, 'AR'):
        print('\t', track[1])
# Out:
# The Book of Souls: Live Chapter
# 	 If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016
# 	 Speed of Light - Live at Grand Arena, GrandWest, Cape Town, South Africa, Wednesday, 5/18/2016
# 	 Wrathchild - Live at 3 Arena, Dublin, Ireland, Saturday, 5/6/2017
# 	 Children of the Damned - Live at Bell Center, Montreal, Canada, Friday, 4/1/2016
# 	 Death or Glory - Live at Wroclaw Stadium, Wroclaw, Poland, Sunday, 7/3/2016
# 	 The Red and the Black - Live at Ryogoku Kokugikan, Tokyo, Japan, Thursday, 4/21/2016
# 	 The Trooper - Live at Estadio Jorge Magico Gonzalez, San Salvador, El Salvador, Sunday, 3/6/2016
# 	 Powerslave - Live at Plaza Dell'Unita D'Italia, Trieste, Italy, Tuesday, 7/26/2016
# 	 The Great Unknown - Live at MRA Arena, Newcastle, England, Sunday, 5/14/2017
# 	 The Book of Souls - Live at Download Festival, Donington, England, Sunday, 6/12/2016
# 	 Fear of the Dark - Live at Arena Castelao, Fortaleza, Brazil, Thursday, 3/24/2016
# ...

# %% [markdown]
# ### Sorpresa

# %%
preview_url = 'https://p.scdn.co/mp3-preview/70e37e343bba05b2c2be40f2c3f84ec85205929a?cid=1cb09af9e89c44fe9edfa4d39cbb0f0f'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
